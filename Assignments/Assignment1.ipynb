# %% [markdown]
# <a href="https://colab.research.google.com/github/mhrznamrit/dsml_batch_12/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "my name is amrit maharjan"
string = "I am learning Python"
data = "Hello, World!"
new = "i use colab"
data1 = "     Java     "
data2 = "#####HTML*****"
animals = "lion tiger bear fox"
food = ['momo', 'chowmein', 'pizza', 'burger']
file_name = "report about class.pdf"
name = "John"
num = "1234567890"

# %%
data.lower()
# Out:
# 'hello, world!'

# %%
string.upper()
# Out:
# 'I AM LEARNING PYTHON'

# %%
new.capitalize()
# Out:
# 'I use colab'

# %%
new.title()
# Out:
# 'I Use Colab'

# %%
data1.strip()
# Out:
# 'Java'

# %%
data2.strip('#*')
# Out:
# 'HTML'

# %%
data1.lstrip()
# Out:
# 'Java     '

# %%
data1.rstrip()
# Out:
# '     Java'

# %%
text.replace("my name is","I am")
# Out:
# 'I am amrit maharjan'

# %%
animals.split()
# Out:
# ['lion', 'tiger', 'bear', 'fox']

# %%
",".join(food)
# Out:
# 'momo,chowmein,pizza,burger'

# %%
string.find("P")
# Out:
# 14

# %%
string.index("y")
# Out:
# 15

# %%
data.count("l")
# Out:
# 3

# %%
file_name.startswith("report")
# Out:
# True

# %%
file_name.endswith("pdf")
# Out:
# True

# %%
data1.isalnum()
# Out:
# False

# %%
name.isalpha()
# Out:
# True

# %%
num.isdigit()
# Out:
# True

# %%
data1.isspace()
# Out:
# False

# %%
new.islower()
# Out:
# True

# %%
data.isupper()
# Out:
# False
