# %% [markdown]
# <a href="https://colab.research.google.com/github/mhrznamrit/dsml_batch_12/blob/main/Day4_string_and_python_data_structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **STRINGS**

# %%
data = 'hello'

# %%
type (data)
# Out:
# str

# %%
data = "Python"

# %%
data[0]
# Out:
# 'P'

# %%
data[-6]
# Out:
# 'P'

# %%
data="How're you feeling?"

# %%
data
# Out:
# "How're you feeling?"

# %%
data = 'I am a "man"'
data
# Out:
# 'I am a "man"'

# %%
#For comment
'''Hello'''
"""Hello"""
# Out:
# 'Hello'

# %% [markdown]
# # String Operations
# * Concatenation (+)
# * Repetition (*)
# * Indexing and slicing
# * Length using len()

# %%
#Concatenation
data1 = 'Amrit'
data2 = 'Maharjan'
data1 + data2
# Out:
# 'AmritMaharjan'

# %%
result = data1 + " " + data2
result
# Out:
# 'Amrit Maharjan'

# %%
#Repetition
data1 * 2
# Out:
# 'AmritAmrit'

# %%
data_= "Python"

# %%
data_[1:4]
# Out:
# 'yth'

# %%
data_new = "Hello, I am learning Python"
data_new[2:20:2]

#[start:end:step]
# Out:
# 'lo  mlann'

# %%
data = "Python"
data[0:2]
# Out:
# 'Py'

# %%
data[:-4]
# Out:
# 'Py'

# %%
data[3:]
# Out:
# 'hon'

# %%
data[::-1]
# Out:
# 'nohtyP'

# %%
data_new = "Hello, I am learning Python"
len(data_new)
# Out:
# 27

# %% [markdown]
# # String Operations
# * upper(), lower(), title()
# * strip(), replace()
# * split(), join()

# %%
string1 = "hello"
string1.upper()
# Out:
# 'HELLO'

# %%
string2 = "NAMASTE"
string2.lower()
# Out:
# 'namaste'

# %%
string1.title()
# Out:
# 'Hello'

# %%
string2.title()
# Out:
# 'Namaste'

# %%
string = "        Hello, world !            "
string.strip()
#strip removes leading and trailing whitespace
# Out:
# 'Hello, world !'

# %%
text = "#####Python*****"
text.strip("#*")
# Out:
# 'Python'

# %%
text = "I like Java"
text.replace("Java","Python")
# Out:
# 'I like Python'

# %%
text = "apple, banana, cherry"
text.split(",")
# Out:
# ['apple', ' banana', ' cherry']

# %%
letters = ["P","Y","T","H","O","N"]
"".join(letters)
# Out:
# 'PYTHON'

# %%
" ".join(letters)
# Out:
# 'P Y T H O N'

# %%
data = "file.pdf"
data.endswith("pdf")
# Out:
# True
