# %% [markdown]
# <a href="https://colab.research.google.com/github/mhrznamrit/dsml_batch_12/blob/main/Day3_number_and_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5

# %%
a
# Out:
# 5

# %%
#key value pair
data = {
    "Name": "Ram"
}

# %%
data
# Out:
# {'Name': 'Ram'}

# %%
1,2,3,4 #integer
1.2,2.4,3.7 #float
2+2j #complex
# Out:
# (2+2j)

# %%
type(a)
# Out:
# int

# %%
pi = 22/7

# %%
pi
# Out:
# 3.142857142857143

# %%
type(pi)
# Out:
# float

# %%
num = 4+ 2j

# %%
type(num)
# Out:
# complex

# %%
age=20.9

# %%
age = int(age)
age
# Out:
# 20

# %%
a=3/2
a
# Out:
# 1.5

# %%
a=5
b=3
c=5
d=7

# %%
a!=b
# Out:
# True

# %%
a==c
# Out:
# True

# %%
d<a
# Out:
# False

# %%
c>b
# Out:
# True

# %%
import math

# %%
math.floor(45.9)
# Out:
# 45

# %%
math.ceil(49.1)
# Out:
# 50

# %%
math.gcd(4,36,92)
# Out:
# 4

# %%
round(2.345636,2)
# Out:
# 2.35
