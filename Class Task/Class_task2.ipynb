# %% [markdown]
# <a href="https://colab.research.google.com/github/mhrznamrit/dsml_batch_12/blob/main/Class_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Create a dictionary to store student name, age, and faculty.
# 2. Add a new key called phone to an existing dictionary.
# 3. Update the value of age in a dictionary.
# 4. Remove a key named city from a dictionary using del.
# 5. Check whether the key email exists in a dictionary.

# %%
student = dict({
    "Name" : "John",
    "Age" : 24,
    "Faculty" : "Psychology"
})
student
# Out:
# {'Name': 'John', 'Age': 24, 'Faculty': 'Psychology'}

# %%
student["Phone"] = 9876543210
student
# Out:
# {'Name': 'John', 'Age': 24, 'Faculty': 'Psychology', 'Phone': 9876543210}

# %%
student["Age"] = 22
student
# Out:
# {'Name': 'John', 'Age': 22, 'Faculty': 'Psychology', 'Phone': 9876543210}

# %%
student["City"] = "London"
student
# Out:
# {'Name': 'John',
#  'Age': 22,
#  'Faculty': 'Psychology',
#  'Phone': 9876543210,
#  'City': 'London'}

# %%
del student["City"]

# %%
student
# Out:
# {'Name': 'John', 'Age': 22, 'Faculty': 'Psychology', 'Phone': 9876543210}

# %%
if "Email" in student:
  print("Email key exists")
else:
  print("Email key doesn't exist")
# Out:
# Email key doesn't exist
