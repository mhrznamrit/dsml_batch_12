# %% [markdown]
# <a href="https://colab.research.google.com/github/mhrznamrit/dsml_batch_12/blob/main/Class_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a list of 5 favorite fruits. Add one more
# fruit using append() and print the updated list.

# %%
fruit = ["apple", "mango", "banana", "orange", "papaya"]

# %%
fruit.append("kiwi")
fruit
# Out:
# ['apple', 'mango', 'banana', 'orange', 'papaya', 'kiwi']

# %% [markdown]
# Create a list of numbers from 1 to 5. Remove
# the last item using pop() and print the final list.

# %%
num = [1,2,3,4,5]

# %%
num.pop()
# Out:
# 5

# %%
num
# Out:
# [1, 2, 3, 4]
