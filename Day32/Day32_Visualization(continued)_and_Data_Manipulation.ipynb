# %% [markdown]
# <a href="https://colab.research.google.com/github/mhrznamrit/dsml_batch_12/blob/main/Day32_Visualization(continued)_and_Data_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("/content/drive/MyDrive/DSML12/titanic-data.csv")

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_df["Age"].plot.bar()
# Out:
# <Axes: >

# %%
titanic_df["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_df["Age"].plot.hist(bins=20, grid =True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import cv2
import matplotlib.pyplot as plt

# Load image in grayscale
img1 = cv2.imread('/content/img1.png', 0)
img2 = cv2.imread('/content/img2.png', 0)

# Calculate and plot histogram
hist = cv2.calcHist([img1], [0], None, [256], [0, 256])
plt.plot(hist)
plt.xlim([0, 256])
plt.show()

hist = cv2.calcHist([img2], [0], None, [256], [0, 256])
plt.plot(hist)
plt.xlim([0, 256])
plt.show()

# %%
titanic_df.plot.box(column ="Age")
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
correlation = titanic_df.corr(numeric_only=True)
correlation
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(correlation, annot = True, cmap='jet')
# Out:
# <Axes: >

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
x = np.random.standard_t(500, size=1000)

# %%
x[:15]
# Out:
# array([ 1.00812532, -0.21565738, -0.92506847, -0.70152122,  1.55492591,
#        -1.11119887,  0.8153937 ,  0.389172  , -0.05213117,  1.02566819,
#         1.54982644,  1.53078549,  1.39276569, -0.80560906, -1.53149417])

# %%
_mean = np.mean(x)

print(f"Mean of x: {_mean}")
# Out:
# Mean of x: 0.061577762350688084

# %%
plt.hist(x, bins=20, color="blue")
# Out:
# (array([  1.,   6.,   8.,  21.,  46.,  66.,  82., 102., 129., 136., 105.,
#         102.,  89.,  52.,  31.,  14.,   7.,   0.,   2.,   1.]),
#  array([-2.96699579, -2.64062952, -2.31426325, -1.98789699, -1.66153072,
#         -1.33516445, -1.00879819, -0.68243192, -0.35606565, -0.02969939,
#          0.29666688,  0.62303315,  0.94939941,  1.27576568,  1.60213195,
#          1.92849822,  2.25486448,  2.58123075,  2.90759702,  3.23396328,
#          3.56032955]),
#  <BarContainer object of 20 artists>)

# %%
plt.axvline(x=_mean, color="red")

# %%
plt.hist(x, bins=20, color="blue")
plt.axvline(x=_mean, color="red")

# %%
_median = np.median(x)
print(f"Median of x: {_median}")
# Out:
# Median of x: 0.07153243638640255

# %%
plt.hist(x, bins=20, color='blue')
plt.axvline(x=_median, color='yellow')

# %%
plt.hist(x, bins=20, color='blue')
plt.axvline(x=_mean, color='red')
plt.axvline(x=_median, color='yellow')

# %%
_mode = stats.mode(x).mode
print("Mode:",_mode)
# Out:
# Mode: -2.96699578713431

# %%
plt.hist(x, color="blue")
plt.axvline(_mode, color="red")
plt.show()
