# %% [markdown]
# <a href="https://colab.research.google.com/github/mhrznamrit/dsml_batch_12/blob/main/Day6_Tuple_and_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TUPLE**

# %%
tup = (1, 2, 3, "John", "Mary")

# %%
type(tup)
# Out:
# tuple

# %%
data1 = [1,2,3,4,5]
type(data1)
# Out:
# list

# %%
data2 = tuple(data1)
type(data2)
# Out:
# tuple

# %%
data3 = list(tup)
type(data3)
# Out:
# list

# %% [markdown]
# # Tuple Functions in Python

# %%
new_data = (10,20,30,40,50,60,70)

# %%
len(new_data)
# Out:
# 7

# %%
max(new_data)
# Out:
# 70

# %%
min(new_data)
# Out:
# 10

# %%
sum(new_data)
# Out:
# 280

# %%
any(new_data)
# Out:
# True

# %%
all(new_data)
# Out:
# True

# %%
sorted(new_data)
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
tuple(new_data)
# Out:
# (10, 20, 30, 40, 50, 60, 70)

# %%
data = (1,2,3)

# %%
s = sorted(data)
s
# Out:
# [1, 2, 3]

# %%
type(s)
# Out:
# list

# %% [markdown]
# # Tuple Packing & Unpacking in Python

# %%
data_pack = 1, 2.0, "three"
data_pack
# Out:
# (1, 2.0, 'three')

# %%
type(data_pack)
# Out:
# tuple

# %%
a, b, c = data_pack

# %%
print(a)
print(b)
print(c)
# Out:
# 1
# 2.0
# three

# %%
a, b, _ = data_pack

# %%
percentages = (99,95,90,97,89,96)
a,b,c,d,e,f = percentages
c
# Out:
# 90

# %% [markdown]
# # Tuples Operation
# * Indexing
# * Slicing
# * Concatenation
# * Repetition
# * Membership
# * Comparison

# %%
dat = (70,80,80,90)
dat[1]
# Out:
# 80

# %%
dat[1:3]
# Out:
# (80, 80)

# %%
t1 = (2,3)
t2 = (4,9)
t1 + t2
# Out:
# (2, 3, 4, 9)

# %%
t1 * 3
# Out:
# (2, 3, 2, 3, 2, 3)

# %%
t3 = (30,40,50,40,60,40,50)
40 in t3
# Out:
# True

# %%
t1<t2
# Out:
# True

# %%
t1>t2
# Out:
# False

# %% [markdown]
# # **SET**

# %%
data = {1,2,3,4,5}

# %%
type(data)
# Out:
# set

# %%
data1 = {1,3,1,4,3,2,1,5}
data1
# Out:
# {1, 2, 3, 4, 5}

# %%
data2 = [1,2,4,8,4.5,16,32,0.5,2,4,8,4]
data3 = set(data2)
data3
# Out:
# {0.5, 1, 2, 4, 4.5, 8, 16, 32}

# %% [markdown]
# # Python Set Operation
# * Union (|)
# * Intersection (&)
# * Difference (-)
# * Symmetric Difference (^)
# * Membership (in)
# * Subset (<=)

# %%
A = {1,2,3,4,5}
B = {4,5,6,7,8}

# %%
A|B
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A&B
# Out:
# {4, 5}

# %%
A-B
# Out:
# {1, 2, 3}

# %%
B-A
# Out:
# {6, 7, 8}

# %%
(A-B) | (B-A)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
(A|B) - (A&B)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
A^B
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
2 in A
# Out:
# True

# %%
3 in B
# Out:
# False

# %%
# Subset
P = {1,2,3}
Q = {1,2,3,4,5}
P<=Q
# Out:
# True
