# %% [markdown]
# <a href="https://colab.research.google.com/github/mhrznamrit/dsml_batch_12/blob/main/Day3_number_and_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PYTHON NUMBERS

# %%
a = 5

# %%
a
# Out:
# 5

# %%
#key value pair (Dictionary)
data = {
    "Name": "Ram"
}

# %%
data
# Out:
# {'Name': 'Ram'}

# %% [markdown]
# Python Numerical Types
# ---
# *   Integers : 1, 2, 3, 4, 5
#
# *   Floating-Point Numbers : 1.5, 2.77, 3.0, 5.999
#
# *   Complex Numbers : 6-3j, 4+9j

# %%
a = 100

# %%
type(a)
# Out:
# int

# %%
pi = 22/7

# %%
pi
# Out:
# 3.142857142857143

# %%
type(pi)
# Out:
# float

# %%
num = 4+ 2j

# %%
type(num)
# Out:
# complex

# %%
age=20.9

# %%
age = int(age)
age
# Out:
# 20

# %% [markdown]
# # Arithmetic Operations
# *   Addition +
# *   Subtraction -
# *   Multiplication *
# *   Division /
# *   Modulus %
# *   Exponentiation **
# *   Floor Division //

# %%
2 + 3
# Out:
# 5

# %%
9 - 1
# Out:
# 8

# %%
4 * 7
# Out:
# 28

# %%
3 / 2
# Out:
# 1.5

# %%
18 % 5
# Out:
# 3

# %%
4 ** 3
# Out:
# 64

# %%
27 // 5
# Out:
# 5

# %% [markdown]
# # Comparison Operators
# * '==' Equal to
# * '!=' Not equal to
# * '>' Greater than
# * '<' Less than
# * '>=' Greater than or equal to
# * '<=' Less than or equal to

# %%
a=5
b=3
c=5
d=7

# %%
a!=b
# Out:
# True

# %%
a==c
# Out:
# True

# %%
d<a
# Out:
# False

# %%
c>b
# Out:
# True

# %% [markdown]
# # **Math Functions**

# %%
import math

# %%
math.floor(45.9)
# Out:
# 45

# %%
math.ceil(49.1)
# Out:
# 50

# %%
math.gcd(4,36,92)
# Out:
# 4

# %%
round(2.345636,2)
# Out:
# 2.35
